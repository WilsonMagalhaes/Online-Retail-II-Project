# %%
import pandas as pd
df = pd.read_csv('/content/cleaned_data_online_retail_II.csv')

df.head()
# Out:
#    Invoice StockCode                          Description  Quantity  \
# 0   489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1   489434    79323P                   PINK CHERRY LIGHTS        12
# 2   489434    79323W                  WHITE CHERRY LIGHTS        12
# 3   489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4   489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
#
#            InvoiceDate  Price  Customer ID         Country
# 0  2009-12-01 07:45:00   6.95      13085.0  United Kingdom
# 1  2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 2  2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 3  2009-12-01 07:45:00   2.10      13085.0  United Kingdom
# 4  2009-12-01 07:45:00   1.25      13085.0  United Kingdom

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 378482 entries, 0 to 378481
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Invoice      378482 non-null  int64
#  1   StockCode    378482 non-null  object
#  2   Description  378482 non-null  object
#  3   Quantity     378482 non-null  int64
#  4   InvoiceDate  378482 non-null  object
#  5   Price        378482 non-null  float64
#  6   Customer ID  378482 non-null  float64
#  7   Country      378482 non-null  object
# dtypes: float64(2), int64(2), object(4)
# memory usage: 23.1+ MB

# %%
df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'])

# %%
#Invoices per country
df.groupby('Country')['Invoice'].nunique().sort_values(ascending=False)
# Out:
# Country
# United Kingdom          17247
# EIRE                      283
# Germany                    69
# Netherlands                67
# France                     56
# Sweden                     41
# Australia                  35
# Channel Islands            30
# Spain                      26
# Cyprus                     19
# Denmark                    16
# Switzerland                16
# Japan                      16
# Italy                      13
# Portugal                   12
# Greece                     12
# USA                        10
# Poland                      9
# Unspecified                 8
# Norway                      8
# Austria                     8
# Finland                     7
# United Arab Emirates        7
# Lithuania                   6
# Singapore                   4
# Belgium                     3
# Thailand                    2
# Korea                       2
# Malta                       2
# Israel                      2
# Iceland                     2
# Canada                      2
# Bahrain                     2
# RSA                         1
# Nigeria                     1
# Brazil                      1
# West Indies                 1
# Name: Invoice, dtype: int64

# %%
#Most revenue per country
df['Revenue'] = df['Quantity'] * df['Price']
df.groupby('Country')['Revenue'].sum().sort_values(ascending=False)
# Out:
# Country
# United Kingdom          7254296.83
# EIRE                     338505.09
# Netherlands              246927.26
# Germany                   56861.32
# France                    48842.25
# Denmark                   45869.31
# Sweden                    41111.13
# Switzerland               33131.48
# Australia                 30313.35
# Spain                     28499.59
# Channel Islands           24546.32
# Greece                    14057.74
# Cyprus                    10391.00
# Japan                      9722.02
# Norway                     9542.53
# Portugal                   9207.64
# United Arab Emirates       7032.41
# Italy                      6860.81
# Austria                    6308.25
# Unspecified                5946.58
# Lithuania                  4892.68
# Finland                    4310.11
# Singapore                  4037.77
# USA                        3832.37
# Israel                     3199.40
# Poland                     3193.05
# Thailand                   3070.54
# Malta                      2686.75
# Belgium                    2066.53
# Iceland                    1323.32
# Canada                     1216.66
# Korea                      1118.51
# RSA                         931.43
# Bahrain                     805.97
# West Indies                 536.41
# Brazil                      268.27
# Nigeria                     112.57
# Name: Revenue, dtype: float64

# %%
#Revenue per customer
df.groupby('Customer ID')['Revenue'].sum().sort_values(ascending=False)
# Out:
# Customer ID
# 18102.0    349164.35
# 14646.0    245110.78
# 14156.0    187849.00
# 14911.0    143593.89
# 13694.0    131443.19
#              ...
# 12417.0         8.50
# 15040.0         7.49
# 15913.0         6.30
# 13788.0         3.75
# 14095.0         2.95
# Name: Revenue, Length: 4093, dtype: float64

# %%
#Quantity of products sold per customer
df.groupby('Customer ID')['Quantity'].sum().sort_values(ascending=False)
# Out:
# Customer ID
# 13902.0    220506
# 14646.0    168680
# 13694.0    125893
# 18102.0    124216
# 14156.0    108096
#             ...
# 14095.0         1
# 12675.0         1
# 15040.0         1
# 18227.0         1
# 14086.0         1
# Name: Quantity, Length: 4093, dtype: int64

# %%
#Most invoices per customer
df.groupby('Customer ID')['Invoice'].nunique().sort_values(ascending=False)
# Out:
# Customer ID
# 14911.0    185
# 17850.0    155
# 12748.0    127
# 15311.0    118
# 13089.0    109
#           ...
# 14052.0      1
# 13303.0      1
# 15391.0      1
# 16857.0      1
# 16396.0      1
# Name: Invoice, Length: 4093, dtype: int64

# %%
#Most expensive invoices
df.groupby('Invoice')['Revenue'].sum().sort_values(ascending=False)
# Out:
# Invoice
# 493819    44051.60
# 524181    34172.20
# 526934    26007.08
# 515944    22863.36
# 517731    21984.00
#             ...
# 497589        0.95
# 529158        0.95
# 514662        0.85
# 509152        0.85
# 502668        0.84
# Name: Revenue, Length: 18046, dtype: float64

# %%
#Products most sold
df.groupby('Description')['Quantity'].sum().sort_values(ascending=False)
# Out:
# Description
# WHITE HANGING HEART T-LIGHT HOLDER    56247
# WORLD WAR 2 GLIDERS ASSTD DESIGNS     53553
# BROCADE RING PURSE                    47790
# PACK OF 72 RETRO SPOT CAKE CASES      43427
# ASSORTED COLOUR BIRD ORNAMENT         43237
#                                       ...
# F FAIRY POTPOURRI CUSHIONS SUMMER         1
# RED SPOTTY PASSPORT COVER                 1
# AMBER CRYSTAL DROP EARRINGS               1
# OPAL WHITE/SILVER FLOWER NECKLACE         1
# PINK STRIPES SHOULDER BAG                 1
# Name: Quantity, Length: 4423, dtype: int64

# %%
#Revenue per product
df.groupby('Description')['Revenue'].sum().sort_values(ascending=False)
# Out:
# Description
# WHITE HANGING HEART T-LIGHT HOLDER     149730.51
# REGENCY CAKESTAND 3 TIER               138779.10
# ASSORTED COLOUR BIRD ORNAMENT           68349.97
# JUMBO BAG RED RETROSPOT                 50132.55
# ROTATING SILVER ANGELS T-LIGHT HLDR     39873.00
#                                          ...
# HANGING SPRING FLOWER HEART SMALL           0.65
# SILICON CUBE 25W, BLUE                      0.42
# CHAMPAGNE TRAY BLANK CARD                   0.38
# PINK HEART CHRISTMAS DECORATION             0.38
# FOLDING CAMPING SCISSOR W/KNIF & S          0.24
# Name: Revenue, Length: 4423, dtype: float64

# %%
#Most sold products in the United Kingdom
df[df['Country']=='United Kingdom'].groupby('Description')['Quantity'].sum().sort_values(ascending=False)
# Out:
# Description
# WHITE HANGING HEART T-LIGHT HOLDER    51240
# WORLD WAR 2 GLIDERS ASSTD DESIGNS     50961
# BROCADE RING PURSE                    47746
# ASSORTED COLOUR BIRD ORNAMENT         41143
# PACK OF 72 RETRO SPOT CAKE CASES      35154
#                                       ...
# S/3 COLOURS FLOCK TEA TOWELS              1
# CRYSTAL SMALL JEWELLED PHOTOFRAME         1
# NUMBER TILE VINTAGE FONT 5                1
# FIRE POLISHED GLASS BRACELET RED          1
# 6 HOOK JEWEL STAND LILAC DRESS            1
# Name: Quantity, Length: 4397, dtype: int64

# %%
#Countries with the most customers
df.groupby('Country')['Customer ID'].nunique().sort_values(ascending=False)
# Out:
# Country
# United Kingdom          3917
# France                    20
# Germany                   20
# Australia                 15
# Spain                     12
# Channel Islands           11
# Switzerland                8
# Sweden                     8
# Cyprus                     7
# Portugal                   7
# Italy                      7
# Japan                      6
# Denmark                    5
# USA                        5
# Unspecified                4
# United Arab Emirates       4
# Austria                    4
# Belgium                    3
# Netherlands                3
# Greece                     3
# Norway                     3
# EIRE                       3
# Poland                     2
# Korea                      2
# Israel                     2
# Finland                    2
# Bahrain                    2
# Nigeria                    1
# Malta                      1
# RSA                        1
# Singapore                  1
# Lithuania                  1
# Iceland                    1
# Thailand                   1
# Canada                     1
# Brazil                     1
# West Indies                1
# Name: Customer ID, dtype: int64

# %%
df.set_index('InvoiceDate', inplace=True)

# %%
df.head()
# Out:
#                      Invoice StockCode                          Description  \
# InvoiceDate
# 2009-12-01 07:45:00   489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS
# 2009-12-01 07:45:00   489434    79323P                   PINK CHERRY LIGHTS
# 2009-12-01 07:45:00   489434    79323W                  WHITE CHERRY LIGHTS
# 2009-12-01 07:45:00   489434     22041         RECORD FRAME 7" SINGLE SIZE
# 2009-12-01 07:45:00   489434     21232       STRAWBERRY CERAMIC TRINKET BOX
#
#                      Quantity  Price  Customer ID         Country  Revenue
# InvoiceDate
# 2009-12-01 07:45:00        12   6.95      13085.0  United Kingdom     83.4
# 2009-12-01 07:45:00        12   6.75      13085.0  United Kingdom     81.0
# 2009-12-01 07:45:00        12   6.75      13085.0  United Kingdom     81.0
# 2009-12-01 07:45:00        48   2.10      13085.0  United Kingdom    100.8
# 2009-12-01 07:45:00        24   1.25      13085.0  United Kingdom     30.0

# %%
#See all the possible frequencies
#https://pandas.pydata.org/pandas-docs/stable/user_guide/timeseries.html#offset-aliases

# %%
#Total revenue per calendar day
df.groupby(pd.Grouper(freq='D'))['Revenue'].sum().sort_values(ascending=False)
# Out:
# InvoiceDate
# 2010-09-27    99496.71
# 2010-10-14    84650.74
# 2010-11-04    83811.98
# 2010-01-07    72803.43
# 2010-11-10    71526.21
#                 ...
# 2010-01-03        0.00
# 2010-05-31        0.00
# 2010-10-16        0.00
# 2010-06-05        0.00
# 2010-07-10        0.00
# Name: Revenue, Length: 374, dtype: float64

# %%
#Total revenue per week
df.groupby(pd.Grouper(freq='W'))['Revenue'].sum().sort_values(ascending=False)
# Out:
# InvoiceDate
# 2010-10-17    278564.47
# 2010-10-03    278110.08
# 2010-11-14    269892.73
# 2010-11-07    252183.05
# 2010-12-05    245006.17
# 2010-11-21    238255.31
# 2010-11-28    231893.97
# 2010-10-10    231087.94
# 2009-12-06    226846.16
# 2010-09-26    216762.89
# 2010-10-24    209040.01
# 2009-12-13    202173.91
# 2009-12-20    201566.25
# 2010-06-13    192764.51
# 2010-10-31    181730.40
# 2010-01-10    161444.02
# 2010-05-02    159238.50
# 2010-07-04    155630.41
# 2010-12-12    152793.72
# 2010-02-21    152486.15
# 2010-08-22    149716.97
# 2010-05-16    148002.99
# 2010-03-28    147138.25
# 2010-09-19    142932.70
# 2010-03-21    142216.89
# 2010-02-28    142208.34
# 2010-03-07    141643.09
# 2010-05-09    140006.28
# 2010-07-18    139736.44
# 2010-08-01    138929.50
# 2010-05-30    137082.90
# 2010-08-15    134618.23
# 2010-05-23    131749.13
# 2010-08-29    130714.21
# 2010-04-25    129828.40
# 2010-04-18    129617.56
# 2010-07-11    128987.79
# 2010-07-25    127874.00
# 2010-01-31    126393.18
# 2010-06-20    118186.81
# 2010-01-17    116977.72
# 2010-04-11    115895.98
# 2010-04-04    114947.29
# 2010-03-14    112933.68
# 2010-08-08    112729.07
# 2010-01-24    111892.43
# 2010-09-05    111866.70
# 2010-09-12    108803.79
# 2010-02-07    104840.57
# 2010-06-27    100042.08
# 2010-06-06     87116.76
# 2010-02-14     68434.11
# 2009-12-27     34040.76
# 2010-01-03         0.00
# Name: Revenue, dtype: float64

# %%
#Total revenue per semi month (1st to 15th)
df.groupby(pd.Grouper(freq='SMS'))['Revenue'].sum().sort_values(ascending=False)
# Out:
# InvoiceDate
# 2010-11-15    575623.92
# 2010-11-01    522075.78
# 2010-09-15    519895.38
# 2010-10-01    515133.82
# 2009-12-01    477006.35
# 2010-10-15    455061.62
# 2010-03-15    378997.29
# 2010-04-15    336343.83
# 2010-07-15    325674.31
# 2010-08-15    318518.05
# 2010-06-15    304058.94
# 2010-06-01    300057.86
# 2010-02-15    294694.49
# 2010-12-01    292325.25
# 2010-05-15    286855.78
# 2010-05-01    281987.70
# 2010-01-15    267947.12
# 2010-08-01    256898.29
# 2010-03-01    254576.77
# 2010-09-01    250403.76
# 2010-01-01    248760.23
# 2010-07-01    230243.73
# 2010-04-01    211539.57
# 2009-12-15    187620.73
# 2010-02-01    173274.68
# Name: Revenue, dtype: float64

# %%
#Total revenue per month end
df.groupby(pd.Grouper(freq='ME'))['Revenue'].sum().sort_values(ascending=False)
# Out:
# InvoiceDate
# 2010-11-30    1097699.70
# 2010-10-31     970195.44
# 2010-09-30     770299.14
# 2009-12-31     664627.08
# 2010-03-31     633574.06
# 2010-06-30     604116.80
# 2010-08-31     575416.34
# 2010-05-31     568843.48
# 2010-07-31     555918.04
# 2010-04-30     547883.40
# 2010-01-31     516707.35
# 2010-02-28     467969.17
# 2010-12-31     292325.25
# Name: Revenue, dtype: float64

# %%
#Total revenue per quarter end
df.groupby(pd.Grouper(freq='QE'))['Revenue'].sum().sort_values(ascending=False)
# Out:
# InvoiceDate
# 2010-12-31    2360220.39
# 2010-09-30    1901633.52
# 2010-06-30    1720843.68
# 2010-03-31    1618250.58
# 2009-12-31     664627.08
# Name: Revenue, dtype: float64

# %%
#Total revenue per year end
df.groupby(pd.Grouper(freq='YE'))['Revenue'].sum().sort_values(ascending=False)
# Out:
# InvoiceDate
# 2010-12-31    7600948.17
# 2009-12-31     664627.08
# Name: Revenue, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from matplotlib.ticker import FuncFormatter

# %%
meDF = df.groupby(pd.Grouper(freq='ME'))['Revenue'].sum().sort_values(ascending=False).head(10)
meDF = meDF.reset_index()
meDF['InvoiceDate'] = meDF['InvoiceDate'].dt.strftime('%b-%Y')
meDF.head()
ax = meDF.plot(x='InvoiceDate', y='Revenue', kind='bar')
plt.xticks(rotation=45)
plt.ylim(0, meDF['Revenue'].max() * 1.1) #Multiply for 1.1 so the chart goes higher then the max valueu of the revenue (Y axis)
plt.xlabel('Month end')
plt.ylabel('Revenue')
plt.title('Top 10 total revenue per month end')
formatter = FuncFormatter(lambda x, _: f'{x:,.0f}') #Change the Y axis range from 0 to 1 with scientific notation (1eX) to the real values
ax.yaxis.set_major_formatter(formatter)
plt.show()

# %%
ax = df.groupby(pd.Grouper(freq='D'))['Revenue'].sum().plot(kind='line')

# %%
ax = df.groupby(pd.Grouper(freq='SMS'))['Revenue'].sum().plot(kind='line')

# %%
ax = df.groupby(pd.Grouper(freq='ME'))['Revenue'].sum().plot(kind='line')

# %%
ax = df[df['Country']=='United Kingdom'].groupby('Description')['Quantity'].sum().sort_values(ascending=False).head(10).plot(x='Description', y='Revenue', kind='bar')
plt.xlabel('Product')
plt.ylabel('Quantity')
plt.title('Top 10 most sold products in the UK')
plt.show()
